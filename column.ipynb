# %%
import pandas as pd
import matplotlib.pyplot as mat
import seaborn as sea

# %% [markdown]
# #### Importing the libraries pandas ,matplotlib.pyplot an seaborn from python, in order to perform column operations on the dataset.

# %%
brand=pd.read_csv('G:/Adidas Vs Nike - (Tamil).csv')

# %%
brand
# Out:
#                                            Product Name  Product ID  \
# 0     Women's adidas Originals NMD_Racer Primeknit S...      AH2430
# 1                  Women's adidas Originals Sleek Shoes      G27341
# 2                     Women's adidas Swim Puka Slippers      CM0081
# 3      Women's adidas Sport Inspired Questar Ride Shoes      B44832
# 4              Women's adidas Originals Taekwondo Shoes      D98205
# ...                                                 ...         ...
# 3263                                 Air Jordan 8 Retro  CI1236-100
# 3264                         Nike Phantom Venom Club IC  AO0578-717
# 3265               Nike Mercurial Superfly 7 Academy TF  AT7978-414
# 3266                                    Nike Air Max 98  AH6799-300
# 3267                                     Nike P-6000 SE  CJ9585-600
#
#       Listing Price  Sale Price  Discount                    Brand  \
# 0             14999        7499        50  Adidas Adidas ORIGINALS
# ...

# %%
brand.columns
# Out:
# Index(['Product Name', 'Product ID', 'Listing Price', 'Sale Price', 'Discount',
#        'Brand', 'Description', 'Rating', 'Reviews', 'Last Visited'],
#       dtype='object')

# %% [markdown]
# #### Displaying the variable names in the dataset.

# %%
brand['total']=brand['Listing Price']+brand['Sale Price']

# %% [markdown]
# #### Added a new variable in the dataset by combining the variables Listing price and Sale price.

# %%
brand
# Out:
#                                            Product Name  Product ID  \
# 0     Women's adidas Originals NMD_Racer Primeknit S...      AH2430
# 1                  Women's adidas Originals Sleek Shoes      G27341
# 2                     Women's adidas Swim Puka Slippers      CM0081
# 3      Women's adidas Sport Inspired Questar Ride Shoes      B44832
# 4              Women's adidas Originals Taekwondo Shoes      D98205
# ...                                                 ...         ...
# 3263                                 Air Jordan 8 Retro  CI1236-100
# 3264                         Nike Phantom Venom Club IC  AO0578-717
# 3265               Nike Mercurial Superfly 7 Academy TF  AT7978-414
# 3266                                    Nike Air Max 98  AH6799-300
# 3267                                     Nike P-6000 SE  CJ9585-600
#
#       Listing Price  Sale Price  Discount                    Brand  \
# 0             14999        7499        50  Adidas Adidas ORIGINALS
# ...

# %%
brand['low']=brand['Listing Price']/brand['Sale Price']

# %%
brand
# Out:
#                                            Product Name  Product ID  \
# 0     Women's adidas Originals NMD_Racer Primeknit S...      AH2430
# 1                  Women's adidas Originals Sleek Shoes      G27341
# 2                     Women's adidas Swim Puka Slippers      CM0081
# 3      Women's adidas Sport Inspired Questar Ride Shoes      B44832
# 4              Women's adidas Originals Taekwondo Shoes      D98205
# ...                                                 ...         ...
# 3263                                 Air Jordan 8 Retro  CI1236-100
# 3264                         Nike Phantom Venom Club IC  AO0578-717
# 3265               Nike Mercurial Superfly 7 Academy TF  AT7978-414
# 3266                                    Nike Air Max 98  AH6799-300
# 3267                                     Nike P-6000 SE  CJ9585-600
#
#       Listing Price  Sale Price  Discount                    Brand  \
# 0             14999        7499        50  Adidas Adidas ORIGINALS
# ...

# %%
brand.rename(columns={'Sale Price':'Sales'})
# Out:
#                                            Product Name  Product ID  \
# 0     Women's adidas Originals NMD_Racer Primeknit S...      AH2430
# 1                  Women's adidas Originals Sleek Shoes      G27341
# 2                     Women's adidas Swim Puka Slippers      CM0081
# 3      Women's adidas Sport Inspired Questar Ride Shoes      B44832
# 4              Women's adidas Originals Taekwondo Shoes      D98205
# ...                                                 ...         ...
# 3263                                 Air Jordan 8 Retro  CI1236-100
# 3264                         Nike Phantom Venom Club IC  AO0578-717
# 3265               Nike Mercurial Superfly 7 Academy TF  AT7978-414
# 3266                                    Nike Air Max 98  AH6799-300
# 3267                                     Nike P-6000 SE  CJ9585-600
#
#       Listing Price  Sales  Discount                    Brand  \
# 0             14999   7499        50  Adidas Adidas ORIGINALS
# ...

# %% [markdown]
# #### Renamed a 'Sale Price' variable as 'Sales'.

# %%
brand.rename(columns={'Listing Price':'Original Price','total':'final'})
# Out:
#                                            Product Name  Product ID  \
# 0     Women's adidas Originals NMD_Racer Primeknit S...      AH2430
# 1                  Women's adidas Originals Sleek Shoes      G27341
# 2                     Women's adidas Swim Puka Slippers      CM0081
# 3      Women's adidas Sport Inspired Questar Ride Shoes      B44832
# 4              Women's adidas Originals Taekwondo Shoes      D98205
# ...                                                 ...         ...
# 3263                                 Air Jordan 8 Retro  CI1236-100
# 3264                         Nike Phantom Venom Club IC  AO0578-717
# 3265               Nike Mercurial Superfly 7 Academy TF  AT7978-414
# 3266                                    Nike Air Max 98  AH6799-300
# 3267                                     Nike P-6000 SE  CJ9585-600
#
#       Original Price  Sale Price  Discount                    Brand  \
# 0              14999        7499        50  Adidas Adidas ORIGINALS
# ...

# %% [markdown]
# #### Renamed Two variables 'Listing price' as 'Original Price' and 'total' as 'final'.

# %%
brand.drop(['Reviews','Rating'],axis=1)
# Out:
#                                            Product Name  Product ID  \
# 0     Women's adidas Originals NMD_Racer Primeknit S...      AH2430
# 1                  Women's adidas Originals Sleek Shoes      G27341
# 2                     Women's adidas Swim Puka Slippers      CM0081
# 3      Women's adidas Sport Inspired Questar Ride Shoes      B44832
# 4              Women's adidas Originals Taekwondo Shoes      D98205
# ...                                                 ...         ...
# 3263                                 Air Jordan 8 Retro  CI1236-100
# 3264                         Nike Phantom Venom Club IC  AO0578-717
# 3265               Nike Mercurial Superfly 7 Academy TF  AT7978-414
# 3266                                    Nike Air Max 98  AH6799-300
# 3267                                     Nike P-6000 SE  CJ9585-600
#
#       Listing Price  Sale Price  Discount                    Brand  \
# 0             14999        7499        50  Adidas Adidas ORIGINALS
# ...

# %% [markdown]
# #### We have dropped the variables 'Ratings' and 'Reviews' from the dataset.

# %%
brand.columns=[col.upper()for col in brand.columns]

# %%
brand
# Out:
#                                            PRODUCT NAME  PRODUCT ID  \
# 0     Women's adidas Originals NMD_Racer Primeknit S...      AH2430
# 1                  Women's adidas Originals Sleek Shoes      G27341
# 2                     Women's adidas Swim Puka Slippers      CM0081
# 3      Women's adidas Sport Inspired Questar Ride Shoes      B44832
# 4              Women's adidas Originals Taekwondo Shoes      D98205
# ...                                                 ...         ...
# 3263                                 Air Jordan 8 Retro  CI1236-100
# 3264                         Nike Phantom Venom Club IC  AO0578-717
# 3265               Nike Mercurial Superfly 7 Academy TF  AT7978-414
# 3266                                    Nike Air Max 98  AH6799-300
# 3267                                     Nike P-6000 SE  CJ9585-600
#
#       LISTING PRICE  SALE PRICE  DISCOUNT                    BRAND  \
# 0             14999        7499        50  Adidas Adidas ORIGINALS
# ...

# %% [markdown]
# #### Displayed the Variables name of the dataset in the Uppercase.

# %%
brand.columns=[col.lower()for col in brand.columns]

# %%
brand
# Out:
#                                            product name  product id  \
# 0     Women's adidas Originals NMD_Racer Primeknit S...      AH2430
# 1                  Women's adidas Originals Sleek Shoes      G27341
# 2                     Women's adidas Swim Puka Slippers      CM0081
# 3      Women's adidas Sport Inspired Questar Ride Shoes      B44832
# 4              Women's adidas Originals Taekwondo Shoes      D98205
# ...                                                 ...         ...
# 3263                                 Air Jordan 8 Retro  CI1236-100
# 3264                         Nike Phantom Venom Club IC  AO0578-717
# 3265               Nike Mercurial Superfly 7 Academy TF  AT7978-414
# 3266                                    Nike Air Max 98  AH6799-300
# 3267                                     Nike P-6000 SE  CJ9585-600
#
#       listing price  sale price  discount                    brand  \
# 0             14999        7499        50  Adidas Adidas ORIGINALS
# ...

# %% [markdown]
# #### Displayed the Variables name of the dataset in the lowercase.

# %%
brand.sort_values(by=['listing price','sale price'],ascending=[True,False])
# Out:
#                                   product name  product id  listing price  \
# 3148           Nike Air VaporMax Flyknit 2 LXX  AT5673-700              0
# 2693     Nike Mercurial Superfly 7 Elite SE FG  CT1099-093              0
# 2931    Nike Mercurial Superfly 7 Elite MDS FG  BQ5469-703              0
# 3149     Nike Mercurial Superfly 7 Elite SE FG  CT1099-093              0
# 3164    Nike Mercurial Superfly 7 Elite MDS FG  BQ5469-703              0
# ...                                        ...         ...            ...
# 1553   Men's adidas Originals ZX 4000 4D Shoes      EF9624          27999
# 1563   Men's adidas Originals ZX 4000 4D Shoes      EF9623          27999
# 1642  Unisex adidas Running Alphaedge 4D Shoes      FV6106          27999
# 2554   Men's adidas Originals ZX 4000 4D Shoes      BD7927          29999
# 2579   Men's adidas Originals ZX 4000 4D Shoes      BD7865          29999
#
#       sale price  discount                     brand  \
# ...

# %% [markdown]
# #### In this we have sorted two variables 'Listing price' and 'Sale Price' and then we have arranged the variable 'Listing Price' in the ascending order.

# %%
brand.sort_values(by='total',ascending=True)
# Out:
#                                            product name product id  \
# 2044  Men's adidas Swimming Beach Print Maxout Slippers     CL0233
# 2420                     Men's adidas Toe Side Slippers     CL0252
# 147                   Women's adidas Swim Jung Slippers     CM0072
# 2046         Men's adidas Swim Eezay Maxout II Slippers     CM0106
# 2493         Men's adidas Swim Eezay Maxout II Slippers     CM0105
# ...                                                 ...        ...
# 1438            Men's adidas Originals ZX 4000 4D Shoes     EF9625
# 1642           Unisex adidas Running Alphaedge 4D Shoes     FV6106
# 1553            Men's adidas Originals ZX 4000 4D Shoes     EF9624
# 2554            Men's adidas Originals ZX 4000 4D Shoes     BD7927
# 2579            Men's adidas Originals ZX 4000 4D Shoes     BD7865
#
#       listing price  sale price  discount                     brand  \
# 2044            899         449        50         Adidas CORE / NEO
# ...

# %% [markdown]
# #### Sorted the variable named 'total' and arranged its values in ascending order.

# %%
brand.sort_values(by='total')
# Out:
#                                            product name product id  \
# 2044  Men's adidas Swimming Beach Print Maxout Slippers     CL0233
# 2420                     Men's adidas Toe Side Slippers     CL0252
# 147                   Women's adidas Swim Jung Slippers     CM0072
# 2046         Men's adidas Swim Eezay Maxout II Slippers     CM0106
# 2493         Men's adidas Swim Eezay Maxout II Slippers     CM0105
# ...                                                 ...        ...
# 1438            Men's adidas Originals ZX 4000 4D Shoes     EF9625
# 1642           Unisex adidas Running Alphaedge 4D Shoes     FV6106
# 1553            Men's adidas Originals ZX 4000 4D Shoes     EF9624
# 2554            Men's adidas Originals ZX 4000 4D Shoes     BD7927
# 2579            Men's adidas Originals ZX 4000 4D Shoes     BD7865
#
#       listing price  sale price  discount                     brand  \
# 2044            899         449        50         Adidas CORE / NEO
# ...

# %% [markdown]
# #### We have sorted the variable named 'total'.

# %%
brand.drop(['low'],axis=1,inplace=True)

# %% [markdown]
# #### We have dropped the variable named 'low' and used inplace function.

# %%
brand
# Out:
#                                            product name  product id  \
# 0     Women's adidas Originals NMD_Racer Primeknit S...      AH2430
# 1                  Women's adidas Originals Sleek Shoes      G27341
# 2                     Women's adidas Swim Puka Slippers      CM0081
# 3      Women's adidas Sport Inspired Questar Ride Shoes      B44832
# 4              Women's adidas Originals Taekwondo Shoes      D98205
# ...                                                 ...         ...
# 3263                                 Air Jordan 8 Retro  CI1236-100
# 3264                         Nike Phantom Venom Club IC  AO0578-717
# 3265               Nike Mercurial Superfly 7 Academy TF  AT7978-414
# 3266                                    Nike Air Max 98  AH6799-300
# 3267                                     Nike P-6000 SE  CJ9585-600
#
#       listing price  sale price  discount                    brand  \
# 0             14999        7499        50  Adidas Adidas ORIGINALS
# ...

# %%
brand.groupby('sale price').count()
# Out:
#             product name  product id  listing price  discount  brand  \
# sale price
# 449                    1           1              1         1      1
# 499                    4           4              4         4      4
# 599                    8           8              8         8      8
# 600                    1           1              1         1      1
# 649                    3           3              3         3      3
# ...                  ...         ...            ...       ...    ...
# 23999                  5           5              5         5      5
# 24995                  4           4              4         4      4
# 27999                  4           4              4         4      4
# 29999                  2           2              2         2      2
# 36500                  1           1              1         1      1
#
#             description  rating  reviews  last visited  total
# sale price
# ...

# %% [markdown]
# #### By Performing groupby function on Sale Price variable and used count function it is displays us this variable takes place in 227 observations.

# %%
brand=pd.read_csv('G:/Adidas Vs Nike - (Tamil).csv')

# %%
brand
# Out:
#                                            Product Name  Product ID  \
# 0     Women's adidas Originals NMD_Racer Primeknit S...      AH2430
# 1                  Women's adidas Originals Sleek Shoes      G27341
# 2                     Women's adidas Swim Puka Slippers      CM0081
# 3      Women's adidas Sport Inspired Questar Ride Shoes      B44832
# 4              Women's adidas Originals Taekwondo Shoes      D98205
# ...                                                 ...         ...
# 3263                                 Air Jordan 8 Retro  CI1236-100
# 3264                         Nike Phantom Venom Club IC  AO0578-717
# 3265               Nike Mercurial Superfly 7 Academy TF  AT7978-414
# 3266                                    Nike Air Max 98  AH6799-300
# 3267                                     Nike P-6000 SE  CJ9585-600
#
#       Listing Price  Sale Price  Discount                    Brand  \
# 0               NaN        7499        50  Adidas Adidas ORIGINALS
# ...

# %%
print(brand['Listing Price'].isnull().sum())
# Out:
# 2

# %% [markdown]
# #### We have found out that there are two null values present in the 'Listing Price'' variable.

# %%
print(brand.columns.values)
# Out:
# ['Product Name' 'Product ID' 'Listing Price' 'Sale Price' 'Discount'
#  'Brand' 'Description' 'Rating' 'Reviews' 'Last Visited']

# %% [markdown]
# #### Displayed the variables but by using print function.
